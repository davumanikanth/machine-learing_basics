# %%
print("hello world")
# Out:
# hello world

# %%
def hello():
  print("hle")

# %%
hello()
# Out:
# hle

# %%
import numpy as np
import pandas as pd

# %%
# !pip install pandas

# %%
labels = ['a', 'b', 'c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#creatin g a dataframe
#selection and indexing of cloums
#xewRIN  nwq xolumn
#removing columns
#selecting rows
#selcting subsets of rows and coolumsn
#conditional selction

# %%
import pandas as pd

# %%
#crating a dataframe
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df=pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
columns=["name","age","place","salary"]
df=pd.DataFrame(data_list,columns=columns)
df
# Out:
#     name  age     place  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df[["name","place"]]
# Out:
#     name     place
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
df=pd.DataFrame(data_list)
df
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
df[0]
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: 0, dtype: object

# %%
#create a new column

# %%
df["designation"]=["manager","developer","manager","developer"]
df
# Out:
#     name  age     place  salary designation
# 0   John   28  New York   65000     manager
# 1   Anna   34     Paris   70000   developer
# 2  Peter   29    Berlin   62000     manager
# 3  Linda   42    London   85000   developer

# %%
#removing colums

# %%
df.drop(columns="designation")
# Out:
#     name  age     place  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df
# Out:
#     name  age     place  salary designation
# 0   John   28  New York   65000     manager
# 1   Anna   34     Paris   70000   developer
# 2  Peter   29    Berlin   62000     manager
# 3  Linda   42    London   85000   developer

# %%
#selecting rows

# %%
df.loc[[0,1]]
# Out:
#    name  age     place  salary designation
# 0  John   28  New York   65000     manager
# 1  Anna   34     Paris   70000   developer

# %%
df.iloc[3]
# Out:
# name               Linda
# age                   42
# place             London
# salary             85000
# designation    developer
# Name: 3, dtype: object

# %%
df.loc[[0,1]][["place","salary"]]
# Out:
#       place  salary
# 0  New York   65000
# 1     Paris   70000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['salary'].plot(kind='hist', bins=20, title='salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('place').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
#i only want to see the those people whose agi is above 30

# %%
df[df["age"]>30]
# Out:
#     name  age   place  salary designation
# 1   Anna   34   Paris   70000   developer
# 3  Linda   42  London   85000   developer

# %%
# age >30 and city paris

# %%
df[(df["age"]>30 )&(df["place"]=="Paris") ]
# Out:
#    name  age  place  salary designation
# 1  Anna   34  Paris   70000   developer

# %%
#missingd data
#1 finding missing data
#2 removing missing data
#3 filling missing data

# %%
#1 finding missing data

# %%
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [1, 2, 3, 4, 5],
    'C': [1, 2, 3, np.nan, np.nan],
    'D': [1, np.nan, np.nan, np.nan, 5]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.isna()
#used to tell null values
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False   True
# 2   True  False  False   True
# 3  False  False   True   True
# 4  False  False   True  False

# %%
df.isna().sum()
# Out:
# A    1
# B    0
# C    2
# D    3
# dtype: int64

# %%
df.isna().any()
# Out:
# A     True
# B    False
# C     True
# D     True
# dtype: bool

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.dropna()
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
df.dropna(thresh=3)
#Drop rows with less than 3 non-NA values
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 4  5.0  5  NaN  5.0

# %%
#filling the missing data

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.fillna(9)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  9.0
# 2  9.0  3  3.0  9.0
# 3  4.0  4  9.0  9.0
# 4  5.0  5  9.0  5.0

# %%
#differnt value t o each columns

# %%
vlaues={'A':0 ,'B':1,'C':2,'D':3}
df.fillna(value=vlaues)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  3.0
# 2  0.0  3  3.0  3.0
# 3  4.0  4  2.0  3.0
# 4  5.0  5  2.0  5.0

# %%
df.fillna(df.mean())
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  3.0
# 2  3.0  3  3.0  3.0
# 3  4.0  4  2.0  3.0
# 4  5.0  5  2.0  5.0

# %%
#merging joining aconcatination

# %%
import pandas as pd

# %%
employees = pd.DataFrame({
    'employee_id': [1, 2, 3, 4, 5],
    'name': ['John', 'Anna', 'Peter', 'Linda', 'Bob'],
    'department': ['HR', 'IT', 'Finance', 'IT', 'HR']
})

# DataFrame 2: Salary information
salaries = pd.DataFrame({
    'employee_id': [1, 2, 3, 6, 7],
    'salary': [60000, 80000, 65000, 70000, 90000],
    'bonus': [5000, 10000, 7000, 8000, 12000]
})

# %%
employees
# Out:
#    employee_id   name department
# 0            1   John         HR
# 1            2   Anna         IT
# 2            3  Peter    Finance
# 3            4  Linda         IT
# 4            5    Bob         HR

# %%
salaries
# Out:
#    employee_id  salary  bonus
# 0            1   60000   5000
# 1            2   80000  10000
# 2            3   65000   7000
# 3            6   70000   8000
# 4            7   90000  12000

# %%
pd.merge(employees,salaries,on="employee_id")
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000

# %%
pd.merge(employees,salaries,on="employee_id",how="inner")
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000

# %%
pd.merge(employees,salaries,on="employee_id",how="outer")
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN
# 5            6    NaN        NaN  70000.0   8000.0
# 6            7    NaN        NaN  90000.0  12000.0

# %%
pd.merge(employees,salaries,on="employee_id",how="left")
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN

# %%
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2'],
    'B': ['B0', 'B1', 'B2'],
    'C': ['C0', 'C1', 'C2']
})

df2 = pd.DataFrame({
    'A': ['A3', 'A4', 'A5'],
    'B': ['B3', 'B4', 'B5'],
    'C': ['C3', 'C4', 'C5']
})

# %%
pd.concat([df1,df2])
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     A   B   C   A   B   C
# 0  A0  B0  C0  A3  B3  C3
# 1  A1  B1  C1  A4  B4  C4
# 2  A2  B2  C2  A5  B5  C5

# %%
#joining 2 data frames

# %%
df1 = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie']
}, index=[1, 2, 3])

# Second DataFrame
df2 = pd.DataFrame({
    'score': [85, 90, 75]
}, index=[2, 3, 4])

# %%
df1
# Out:
#       name
# 1    Alice
# 2      Bob
# 3  Charlie

# %%
df1.join(df2)
# Out:
#       name  score
# 1    Alice    NaN
# 2      Bob   85.0
# 3  Charlie   90.0

# %%
df1.join(df2,how="outer")
# Out:
#       name  score
# 1    Alice    NaN
# 2      Bob   85.0
# 3  Charlie   90.0
# 4      NaN   75.0

# %%
df2.join(df1,how="outer")
# Out:
#    score     name
# 1    NaN    Alice
# 2   85.0      Bob
# 3   90.0  Charlie
# 4   75.0      NaN

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
#group by category and calculate the sum of sales
df2=df[["Category","Sales"]]
df2
# Out:
#   Category  Sales
# 0        A    100
# 1        B    200
# 2        A    150
# 3        B    250
# 4        A    120
# 5        B    180
# 6        A    200
# 7        B    300

# %%
df2=df2.groupby("Category").sum()
df2
# Out:
#           Sales
# Category
# A           570
# B           930

# %%
df3=df[["Store","Sales"]]

df4=df3.groupby("Store").sum()
df4
# Out:
#        Sales
# Store
# S1       720
# S2       780

# %%
#group by multiiple columns
#group by categoury and store
cat= df.groupby(['Category', 'Store'])['Sales'].sum()

# %%
cat
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %%
df['Sales'].mean()
""" mena median mode min max count std"""
# Out:
# np.float64(187.5)

# %%
df["Sales"].agg(["mean","median","min","max","count","std"])
# Out:
# mean      187.500000
# median    190.000000
# min       100.000000
# max       300.000000
# count       8.000000
# std        66.062741
# Name: Sales, dtype: float64

# %%
#pivot table

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

# %%
df
# Out:
#          Date Product Region  Sales  Units    Rep
# 0  2023-01-01       A   East    813     65   John
# 1  2023-01-02       B   West    777     49   Mary
# 2  2023-01-03       C  North    907     44    Bob
# 3  2023-01-04       D  South    689     97  Alice
# 4  2023-01-05       A   East    326     98   John
# 5  2023-01-06       B   West    711     74   Mary
# 6  2023-01-07       C  North    853     57    Bob
# 7  2023-01-08       D  South    439     37  Alice
# 8  2023-01-09       A   East    451     38   John
# 9  2023-01-10       B   West    385     99   Mary
# 10 2023-01-11       C  North    473     66    Bob
# 11 2023-01-12       D  South    764     53  Alice
# 12 2023-01-13       A   East    202     45   John
# 13 2023-01-14       B   West    576     69   Mary
# 14 2023-01-15       C  North    178     19    Bob
# 15 2023-01-16       D  South    950     30  Alice
# 16 2023-01-17       A   East    112     52   John
# 17 2023-01-18       B   West    289     11   Mary
# ...

# %%
pd.pivot_table(df,index="Region",values="Sales",columns="Product")
# Out:
# Product      A      B      C      D
# Region
# East     380.8    NaN    NaN    NaN
# North      NaN    NaN  529.6    NaN
# South      NaN    NaN    NaN  739.0
# West       NaN  547.6    NaN    NaN

# %%
pd.pivot_table(df,index="Region",values="Sales",columns="Product")

# %%
pd.crosstab(df['Date'],df['Product'])
# Out:
# Product     A  B  C  D
# Date
# 2023-01-01  1  0  0  0
# 2023-01-02  0  1  0  0
# 2023-01-03  0  0  1  0
# 2023-01-04  0  0  0  1
# 2023-01-05  1  0  0  0
# 2023-01-06  0  1  0  0
# 2023-01-07  0  0  1  0
# 2023-01-08  0  0  0  1
# 2023-01-09  1  0  0  0
# 2023-01-10  0  1  0  0
# 2023-01-11  0  0  1  0
# 2023-01-12  0  0  0  1
# 2023-01-13  1  0  0  0
# 2023-01-14  0  1  0  0
# 2023-01-15  0  0  1  0
# 2023-01-16  0  0  0  1
# 2023-01-17  1  0  0  0
# 2023-01-18  0  1  0  0
# 2023-01-19  0  0  1  0
# 2023-01-20  0  0  0  1

# %%
#operatin

# %%
df1 = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
})

# %%
df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
df1.shape
# Out:
# (5, 3)

# %%
df1.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       5 non-null      int64
#  1   B       5 non-null      int64
#  2   C       5 non-null      int64
# dtypes: int64(3)
# memory usage: 252.0 bytes

# %%
df1.describe()
# Out:
#               A          B           C
# count  5.000000   5.000000    5.000000
# mean   3.000000  30.000000  300.000000
# std    1.581139  15.811388  158.113883
# min    1.000000  10.000000  100.000000
# 25%    2.000000  20.000000  200.000000
# 50%    3.000000  30.000000  300.000000
# 75%    4.000000  40.000000  400.000000
# max    5.000000  50.000000  500.000000

# %%
#datafriames applyin g function

# %%
df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
def square(x):
     return x**2

# %%
df1['B']=df1['B'].apply(square)
df1
# Out:
#    A     B    C
# 0  1   100  100
# 1  2   400  200
# 2  3   900  300
# 3  4  1600  400
# 4  5  2500  500

# %%
import numpy as np
import pandas as pd
