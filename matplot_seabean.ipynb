# %%
#data visualization

# %%
#data is just numbers until u turn into a pictures
#matplotlib,distribution plosts categorical plost ,matrix plot ,regression plots cufflinks plotsy,great capstonr projects

# %%
#with code :- m,s,p very hight flexiblity,can integrate into apps,ml pipelines

# %%
#with tools :- limited to what the tool allow ,very tough to integrate with ml pipelines

# %%
#matplotlib

# %%
#matplotliv basics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,5,11)

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y=x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.title("hello")
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
#subplots in matlplotlib

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,4)
plt.subplot(2,2,3)
plt.plot(x,y)

# %%
#object orineted way

# %%
fig=plt.figure(figsize=(20,8),dpi=500)
axis1=fig.add_axes([0.1,0.1,.4,1])
axis1.plot(x,y)
axis2=fig.add_axes([0.3,0.8,.8,.8])
axis2.plot(x,y)

# %%
#types of plots

# %%
plt.scatter(x,y)

# %%
plt.hist(x,y)
# Out:
# (array([1., 1., 3., 3., 3., 0., 0., 0., 0., 0.]),
#  array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#         20.25, 25.  ]),
#  <BarContainer object of 10 artists>)

# %%
from random import sample
data=sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([10., 10., 12., 10., 12., 11.,  8.,  6.,  8., 13.]),
#  array([ 16. , 113.9, 211.8, 309.7, 407.6, 505.5, 603.4, 701.3, 799.2,
#         897.1, 995. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f06e2fbfc80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f06e3024050>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f06e2fbfa70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f06e35ce0f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f06e30248c0>],
#  'means': []}

# %%
#saving plots

# %%
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig('my_plot.png')

# %%
#working with images

# %%
import matplotlib.image as mpimg

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3c3d3e98-51d7-457f-8bf1-0b02787893b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c3d3e98-51d7-457f-8bf1-0b02787893b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img=mpimg.imread('alps-9635920.jpg')
img
# Out:
# array([[[120, 143, 174],
#         [120, 143, 174],
#         [120, 143, 174],
#         ...,
#         [143, 179, 215],
#         [143, 179, 215],
#         [143, 179, 215]],
#
#        [[122, 145, 176],
#         [123, 146, 177],
#         [123, 146, 177],
#         ...,
#         [143, 179, 215],
#         [143, 179, 215],
#         [143, 179, 215]],
#
#        [[126, 150, 178],
#         [126, 150, 178],
#         [126, 150, 178],
#         ...,
#         [143, 179, 215],
#         [143, 179, 215],
#         [143, 179, 215]],
#
#        ...,
#
#        [[159, 153,  55],
#         [155, 151,  52],
#         [160, 156,  57],
#         ...,
#         [176, 180,  67],
#         [174, 181,  67],
#         [174, 181,  67]],
#
#        [[159, 153,  55],
#         [156, 150,  52],
#         [160, 156,  57],
#         ...,
#         [176, 180,  67],
#         [174, 181,  69],
#         [174, 181,  69]],
#
#        [[159, 153,  55],
#         [156, 150,  52],
#         [161, 155,  57],
# ...

# %%
plt.imshow(img)
#plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(5727.5), np.float64(3818.5), np.float64(-0.5))

# %%
#optionsal desiging

# %%
plt.plot(x,y,color='pink')

# %%
#distribution plot
#data in rows and colums 1.age 2.salary 3.gender
#age is qunatative variable
#gender is qualatitaive varialbe
#distributive plot to visulaize the quantitaitive dat
#let us discuss some plot
#1.distplot/histplot
#2.jointplot
#3.pairplot
#4.rugplot

# %%
import seaborn as sns

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(df['total_bill'],bins=100,kde=True)
#dis and hist are same
#curnal density estimater:- how the data is skewed left skewed or right skewed
#sns is used to make good plots

# %%
sns.displot(df['tip'],bins=100,kde=True)

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='scatter')

# %%
#scatter  plot:-this is linear regression

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='kde')

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='hist')

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='reg')

# %%
#pair plot
#

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='sex',palette='rainbow')

# %%
sns.rugplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
#focus on pair ,join

# %%
#CATEGORICALPLOTS
"""
BOXPLOT
VIOLINPLOT
STRIPPLOT
SWARMPLOT
BARPLOT
COUNTPLOT

"""


"""

# %%
import seaborn as sns
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#we connt know who are more male or female
sns.countplot(x=df['sex'],hue=df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(x=df['sex'],y=df['total_bill'])
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#box very important in statcitic
#five point memoru

# %%
sns.boxplot(x=df['day'],y=df['total_bill'],palette="pink")
# Out:
# /tmp/ipython-input-2717853517.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['day'],y=df['total_bill'],palette="pink")
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#dot are outlaire

# %%
"boxplot and violinplot"



" boxpplots aaand violinplots are used to shown the distrubution of categorical data, abox plot show the distributions of quantitative dat in a way that faclilitates comparisons between variables or across levels of a categorical variable the box show the quartiles of the dataset while the whiskers extend to show the rest of the distrubution ,excepth for points that aredeterminded to be outliners using a method that is a function of the inter-quartile range"
# Out:
#   File "/tmp/ipython-input-2139344834.py", line 1
#     "boxplot and violinplot
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
sns.violinplot(x='day',y='total_bill',data=df,palette='rainbow')
# Out:
# /tmp/ipython-input-1480368018.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='day',y='total_bill',data=df,palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#strip plot
"the stripplot will draw a scatter plot where one vaiable is categorica a strip plot can be drwn on its own but it is also a good complementto a box or violin plot in cases where you wnat ot show all observaiton slong with somerepresentation of the underlying distribution"
# Out:
# 'the stripplot will draw a scatter plot where one vaiable is categorica a strip plot can be drwn on its own but it is also a good complementto a box or violin plot in cases where you wnat ot show all observaiton slong with somerepresentation of the underlying distribution'

# %%
#swarmplot
"the swarmplot is similar to stripplot ,but the points are adjustedso that they dont overlap thsi gives a bette repersentaion of the distribtion of values ,althrough it does not scale as well to a large numbers of observations (both in terms of the aility to show all the points and interms of the computation need toa rrange them)"
# Out:
# 'the swarmplot is similar to stripplot ,but the points are adjustedso that they dont overlap thsi gives a bette repersentaion of the distribtion of values ,althrough it does not scale as well to a large numbers of observations (both in terms of the aility to show all the points and interms of the computation need toa rrange them)'

# %%
sns.stripplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#swarmplot and violinplot are little bit same

# %%
sns.violinplot(x='tip',y='day' ,data=df)
sns.swarmplot(x='tip',y='day' ,data=df)
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 9.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='tip', ylabel='day'>
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#matrix plot

"
1.heap map
2. cluster map
3.pivot table heat map
"

# %%
import seaborn as sn
import matplotlib.pyplot as plt

# %%
#heat map

# %%
flights=sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
#heat map :- is there any relation between a and c ,or any relation between b or c to find c? so it is co-relation; there may be positive co-relation or negative co-relation

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tipscorr=df[["total_bill","tip","size"]]

# %%
tips[['total_bill', 'tip', 'size']].corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tipscorr.corr())
# Out:
# <Axes: >

# %%
#skin color:has very high co-relation

# %%
#clustermap

# %%
sns.clustermap(tipscorr.corr(),annot=True)

# %%
#pivot table heat map

# %%
pvtflight=flights.pivot_table(values="passengers",index="month",columns="year")
# Out:
# /tmp/ipython-input-3208577561.py:1: FutureWarning:
#
# The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior

# %%
pvtflight
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %%
sns.heatmap(pvtflight)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
#regression plot :- implot()
is used immal so we will not fully discuuss what ,hwo and where it is use but we will see how it is created and what are the values we can put inside it

# %%
#best fit line wiill be striang between allthee

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x="total_bill",y="tip",data=df)

# %%
sns.lmplot(x="total_bill",y="tip",data=df,hue="sex")

# %%
#plotly and  cufflinks
#CUFFLINKS connects plotly with pandas

# %%
# !pip install plotly

# %%
# !pip install cufflinks
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 25.5 MB/s eta 0:00:00
# ...

# %%
import seaborn as sns
import cufflinks as cf

# %%
import pandas as pd
import numpy as np
from plotly.offline import iplot

# %%
cf.go_offline()
cf.set_config_file(offline=True)
tips['total_bill'].iplot()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...
