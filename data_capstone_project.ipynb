# %%
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-f1c4b996-bce0-46ce-965f-a27ce797c344" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f1c4b996-bce0-46ce-965f-a27ce797c344">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("Countries.csv")

# %%
df
# Out:
#                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# ...

# %%
#whic country has the highest population
df[df['population']==df['population'].max()]['country']
# Out:
# 75    India
# Name: country, dtype: object

# %%
#whic is the capital of the country with highes population

df[df['population']==df['population'].max()][['country','capital_city']]
# Out:
#    country capital_city
# 75   India    New Delhi

# %%
#whic country ha the least population
df[df['population']==df['population'].min()]['country']
# Out:
# 179    Tuvalu
# Name: country, dtype: object

# %%
#give me top 5 countries with hgiest democrattic scor

# %%
df.sort_values(by ='democracy_score',ascending=False,inplace=True)

# %%
df
# Out:
#          country                 country_long              currency  \
# 127       Norway            Kingdom of Norway       Norwegian krone
# 74       Iceland          Republic of Iceland         Iceland krona
# 164       Sweden            Kingdom of Sweden         Swedish krona
# 122  New Zealand                  New Zealand    New Zealand dollar
# 46       Denmark           Kingdom of Denmark          Danish krone
# ..           ...                          ...                   ...
# 156  South Sudan      Republic of South Sudan  South Sudanese Pound
# 174        Tonga             Kingdom of Tonga        Tongan pa'anga
# 170  The Bahamas  Commonwealth of The Bahamas       Bahamian dollar
# 179       Tuvalu                       Tuvalu     Australian dollar
# 187      Vanuatu          Republic of Vanuatu          Vanuatu vatu
#
#     capital_city                     region continent         demonym  \
# 127         Oslo            Northern Europe    Europe       Norwegian
# ...

# %%
#how many total religion are there

# %%
df['region'].value_counts()
# Out:
# region
# Eastern Africa               17
# Western Asia                 17
# Western Africa               16
# Southern Europe              15
# Caribbean                    13
# South America                12
# South-Eastern Asia           11
# Middle Africa                10
# Eastern Europe               10
# Northern Europe              10
# Western Europe                9
# Southern Asia                 9
# Central America               8
# Northern Africa               6
# Micronesia                    5
# Central Asia                  5
# Southern Africa               5
# Eastern Asia                  5
# Melanesia                     4
# Polynesia                     3
# Northern America              2
# Australia and New Zealand     2
# Name: count, dtype: int64

# %%
df['region'].value_counts().count()
# Out:
# np.int64(22)

# %%
#how many countries lie in eastern europe region

# %%
df[df['region']=='Eastern Europe']['country'].count()
# Out:
# np.int64(10)

# %%
df['region'].value_counts()['Eastern Europe']
# Out:
# np.int64(10)

# %%
#who is the political leader of the 2 nd highest populated country

# %%
df.sort_values(by='population',ascending=False,inplace=True)
df['political_leader'].loc[2]
# Out:
# 'Abdelmadjid Tebboune'

# %%
#how many countries are theere whois plitical leaders are unknown

# %%
df['political_leader']=='unknown'
# Out:
# 75     False
# 34     False
# 184    False
# 76     False
# 129    False
#        ...
# 112    False
# 143    False
# 130    False
# 119    False
# 179    False
# Name: political_leader, Length: 194, dtype: bool

# %%
df[df['population'] == df['population'].nlargest(2).iloc[1]]
# Out:
#    country                country_long      currency capital_city  \
# 34   China  People's Republic of China  Chinese yuan      Beijing
#
#           region continent  demonym  latitude  longitude  agricultural_land  \
# 34  Eastern Asia      Asia  Chinese      35.0      105.0          5285080.0
#
#     ...  population  women_parliament_seats_pct  rural_population  \
# 34  ...  1412175000                     24.9412         514596570
#
#     urban_population  press  democracy_score  democracy_type  median_age  \
# 34         897578430   0.99             3.32   Authoritarian        34.5
#
#     political_leader                                     title
# 34        Xi Jinping  General Secretary of the Communist Party
#
# [1 rows x 64 columns]

# %%
df[df['political_leader'].isna()]['country']
# Out:
# 151                   Slovak Republic
# 190                West Bank and Gaza
# 172                       Timor-Leste
# 27                         Cabo Verde
# 160                         St. Lucia
# 161    St. Vincent and the Grenadines
# 159               St. Kitts and Nevis
# Name: country, dtype: object

# %%
#how many country have republic int therir full name

# %%
count=0
def counting(txt):
   global count
   if 'republic' in txt.lower():
    count+=1
   return count

# %%
count1=df['country_long'].apply(counting)

# %%
num_republic_countries = df['country_long'].str.contains('republic', case=False, na=False).sum()
print(f"There are {num_republic_countries} countries with 'Republic' in their full name.")
# Out:
# There are 125 countries with 'Republic' in their full name.

# %%
df
# Out:
#                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# ...
